# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
haha = model.predict(x_test)
print(haha.shape)
haha
# Out:
# (10000, 10)
# array([[0.11473494, 0.05796081, 0.11023194, ..., 0.02880788, 0.14319134,
#         0.05436317],
#        [0.12441626, 0.0963967 , 0.00627058, ..., 0.01858751, 0.53629327,
#         0.12979874],
#        [0.25594875, 0.08187559, 0.02114658, ..., 0.05830413, 0.38458964,
#         0.09824282],
#        ...,
#        [0.02956135, 0.03321886, 0.09667426, ..., 0.12557392, 0.06275184,
#         0.02512611],
#        [0.07096657, 0.09349863, 0.05325233, ..., 0.07924881, 0.09200512,
#         0.04143234],
#        [0.130059  , 0.09477279, 0.09286743, ..., 0.18252856, 0.08014987,
#         0.04963368]], dtype=float32)

# %%
haha.argmax(axis=1)
# Out:
# array([8, 8, 8, ..., 5, 6, 7])

# %%
(haha[:, 1] >= 0.5) * 1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# # 載入 Callbacks
# from keras.callbacks import Callback

# # Record_fp_tp
# class Record_tp_tn(Callback):

#     def __init__(self, val_data, batch_size = 20):
#         super().__init__()
#         self.validation_data = val_data
#         self.batch_size = batch_size

#     def on_train_begin(self, epoch, logs = {}):
#         logs = logs or {}
#         record_items = ["val_tp", "val_tn"]
#         for i in record_items:
#           try:
#               if i not in self.params['metrics']:
#                   self.params['metrics'].append(i)
#           except:
#               self.params['metrics']=i
    
#     def on_epoch_end(self, epoch, logs = {}, thres=0.5):
#         logs = logs or {}
#         y_true = self.validation_data[1].argmax(axis = 1)
#         y_pred = self.model.predict(self.validation_data[0])
#         y_pred = (y_pred[:, 1] >= thres) * 1
        
#         val_tp = sum(y_true*y_pred)
#         val_tn = sum((y_true==0) & (y_pred==0))
        
#         logs["val_tp"] = val_tp
#         logs["val_tn"] = val_tn
        
# rec_tptn = Record_tp_tn(val_data=(x_test, y_test))

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):

    def __init__(self, val_data, batch_size = 20):
        super().__init__()
        self.validation_data = val_data
        self.batch_size = batch_size

    def on_train_begin(self, epoch, logs = {}):
      logs = logs or {}
      record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
      for i in record_items:
          try:
              if i not in self.params['metrics']:
                  self.params['metrics'].append(i)
          except:
              self.params['metrics']=i
  
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0]).argmax(axis=1)

        val_tn = sum((y_true==0) & (y_pred==0))
        val_tp = sum(y_true == y_pred) - val_tn

        logs['val_tn'] = val_tn
        logs['val_tp'] = val_tp
        

rec_tptn = Record_tp_tn(val_data=(x_test, y_test))

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )


# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/25
# 49/49 [==============================] - 10s 208ms/step - loss: 2.2037 - accuracy: 0.2658 - val_loss: 2.1211 - val_accuracy: 0.1990
# Epoch 2/25
# 49/49 [==============================] - 10s 204ms/step - loss: 1.7437 - accuracy: 0.3909 - val_loss: 1.9651 - val_accuracy: 0.2914
# Epoch 3/25
# 49/49 [==============================] - 10s 211ms/step - loss: 1.6202 - accuracy: 0.4353 - val_loss: 1.8237 - val_accuracy: 0.3658
# Epoch 4/25
# 49/49 [==============================] - 9s 189ms/step - loss: 1.5455 - accuracy: 0.4596 - val_loss: 1.7161 - val_accuracy: 0.4053
# Epoch 5/25
# 49/49 [==============================] - 10s 194ms/step - loss: 1.4917 - accuracy: 0.4776 - val_loss: 1.6385 - val_accuracy: 0.4259
